# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings("ignore")
from eval import plot_n_generated_effect_random, plot_n_effect_random, plot_mu_effect_random

# %%
plot_n_generated_effect_random()
# Out:
# Generating and evaluating:  20%|##        | 1/5 [00:00<00:02,  1.67it/s]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2]],
#  'criteria': [0, 1, 2],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 32,
#  'profiles': array([[ 6, 13,  7],
#        [18, 15, 16]])}
#
# ## Restoration rate : 	 87.5%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[254  78   0]
# 	 [  8 137 189]
# 	 [  0   1 333]]
# => Accuracy :	 0.72
# => Precision :	 0.75
# => Recall :	 0.72
# => F1 :	 0.71
# Generating and evaluating:  40%|####      | 2/5 [00:01<00:01,  1.80it/s]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2]],
#  'criteria': [0, 1, 2],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 64,
#  'profiles': array([[ 5, 13,  9],
#        [12, 16, 18]])}
#
# ## Restoration rate : 	 95.3125%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[291  41   0]
# 	 [ 62 221  51]
# 	 [  0  30 304]]
# => Accuracy :	 0.82
# => Precision :	 0.81
# => Recall :	 0.82
# => F1 :	 0.81
# Generating and evaluating:  60%|######    | 3/5 [00:06<00:05,  2.65s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2]],
#  'criteria': [0, 1, 2],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 256,
#  'profiles': array([[ 6,  7,  9],
#        [18, 12, 17]])}
#
# ## Restoration rate : 	 98.4375%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[332   0   0]
# 	 [ 43 285   6]
# 	 [  0   0 334]]
# => Accuracy :	 0.95
# => Precision :	 0.96
# => Recall :	 0.95
# => F1 :	 0.95
# Generating and evaluating:  80%|########  | 4/5 [01:45<00:40, 40.86s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2]],
#  'criteria': [0, 1, 2],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 512,
#  'profiles': array([[ 4, 10,  5],
#        [13, 16, 15]])}
#
# ## Restoration rate : 	 99.8046875%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[332   0   0]
# 	 [  6 328   0]
# 	 [  0   4 330]]
# => Accuracy :	 0.99
# => Precision :	 0.99
# => Recall :	 0.99
# => F1 :	 0.99
# Generating and evaluating: 100%|##########| 5/5 [29:30<00:00, 354.12s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2]],
#  'criteria': [0, 1, 2],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 1024,
#  'profiles': array([[ 3,  1, 10],
#        [ 6, 12, 16]])}
#
# ## Restoration rate : 	 100.0%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[330   2   0]
# 	 [  0 333   1]
# 	 [  0   0 334]]
# => Accuracy :	 1.0
# => Precision :	 1.0
# => Recall :	 1.0
# => F1 :	 1.0

# %%
plot_n_effect_random()
# Out:
# Generating and evaluating:  25%|##5       | 1/4 [00:00<00:00,  3.20it/s]
# Parameters:
# ********************
# {'coalitions': [[0], [1]],
#  'criteria': [0, 1],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 128,
#  'profiles': array([[ 3, 11],
#        [ 6, 16]])}
#
# ## Restoration rate : 	 100.0%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[330   2   0]
# 	 [  0 310  24]
# 	 [  0   0 334]]
# => Accuracy :	 0.97
# => Precision :	 0.98
# => Recall :	 0.97
# => F1 :	 0.97
# Generating and evaluating:  50%|#####     | 2/4 [00:01<00:01,  1.76it/s]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2]],
#  'criteria': [0, 1, 2],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 128,
#  'profiles': array([[ 2,  8,  3],
#        [13, 11, 13]])}
#
# ## Restoration rate : 	 95.3125%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[332   0   0]
# 	 [  8 326   0]
# 	 [  0  31 303]]
# => Accuracy :	 0.96
# => Precision :	 0.96
# => Recall :	 0.96
# => F1 :	 0.96
# Generating and evaluating:  75%|#######5  | 3/4 [00:03<00:01,  1.44s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2], [3], [4]],
#  'criteria': [0, 1, 2, 3, 4],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 128,
#  'profiles': array([[ 1, 12, 13, 12,  9],
#        [11, 15, 17, 14, 16]])}
#
# ## Restoration rate : 	 92.96875%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[293  39   0]
# 	 [ 97 226  11]
# 	 [  3  21 310]]
# => Accuracy :	 0.83
# => Precision :	 0.83
# => Recall :	 0.83
# => F1 :	 0.83
# Generating and evaluating: 100%|##########| 4/4 [00:11<00:00,  2.91s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2], [3], [4], [5], [6]],
#  'criteria': [0, 1, 2, 3, 4, 5, 6],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 128,
#  'profiles': array([[ 5,  2,  3,  6,  5,  5,  5],
#        [ 7, 15, 18, 13,  7, 10,  6]])}
#
# ## Restoration rate : 	 88.28125%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[225 107   0]
# 	 [ 42 238  54]
# 	 [  6  63 265]]
# => Accuracy :	 0.73
# => Precision :	 0.75
# => Recall :	 0.73
# => F1 :	 0.73

# %%
plot_mu_effect_random()
# Out:
# Generating and evaluating:  20%|##        | 1/5 [00:01<00:06,  1.73s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2], [3], [4]],
#  'criteria': [0, 1, 2, 3, 4],
#  'mu': 0.0,
#  'n_ground_truth': 1000,
#  'n_learning_set': 128,
#  'profiles': array([[ 1, 13,  2,  3,  6],
#        [17, 17,  8, 13,  8]])}
#
# ## Restoration rate : 	 81.25%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[312  20   0]
# 	 [  0 141 193]
# 	 [  0   0 334]]
# => Accuracy :	 0.79
# => Precision :	 0.84
# => Recall :	 0.79
# => F1 :	 0.77
# Generating and evaluating:  40%|####      | 2/5 [00:03<00:05,  1.68s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2], [3], [4]],
#  'criteria': [0, 1, 2, 3, 4],
#  'mu': 0.01,
#  'n_ground_truth': 1000,
#  'n_learning_set': 128,
#  'profiles': array([[ 1, 12, 16, 10,  2],
#        [17, 13, 19, 13, 16]])}
#
# ## Restoration rate : 	 81.25%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[321   6   5]
# 	 [ 18 120 196]
# 	 [  4   3 327]]
# => Accuracy :	 0.77
# => Precision :	 0.83
# => Recall :	 0.77
# => F1 :	 0.74
# Generating and evaluating:  60%|######    | 3/5 [00:05<00:03,  1.75s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2], [3], [4]],
#  'criteria': [0, 1, 2, 3, 4],
#  'mu': 0.05,
#  'n_ground_truth': 1000,
#  'n_learning_set': 128,
#  'profiles': array([[ 3, 16,  5,  5,  1],
#        [15, 18, 14,  7, 18]])}
#
# ## Restoration rate : 	 84.375%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[324   8   0]
# 	 [ 36 120 178]
# 	 [  2   9 323]]
# => Accuracy :	 0.77
# => Precision :	 0.81
# => Recall :	 0.77
# => F1 :	 0.74
# Generating and evaluating:  80%|########  | 4/5 [00:07<00:01,  1.95s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2], [3], [4]],
#  'criteria': [0, 1, 2, 3, 4],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 128,
#  'profiles': array([[13,  7,  7,  5,  2],
#        [16, 17,  9, 18, 18]])}
#
# ## Restoration rate : 	 82.8125%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[304  28   0]
# 	 [ 15 172 147]
# 	 [  0   1 333]]
# => Accuracy :	 0.81
# => Precision :	 0.83
# => Recall :	 0.81
# => F1 :	 0.8
# Generating and evaluating: 100%|##########| 5/5 [00:14<00:00,  2.94s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2], [3], [4]],
#  'criteria': [0, 1, 2, 3, 4],
#  'mu': 0.2,
#  'n_ground_truth': 1000,
#  'n_learning_set': 128,
#  'profiles': array([[ 4,  5,  3,  5,  5],
#        [19, 16,  6, 16,  6]])}
#
# ## Restoration rate : 	 86.71875%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[275  57   0]
# 	 [ 65 234  35]
# 	 [  1  17 316]]
# => Accuracy :	 0.82
# => Precision :	 0.82
# => Recall :	 0.83
# => F1 :	 0.82
