# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import warnings
warnings.filterwarnings("ignore")
from eval import plot_n_generated_effect_random, plot_n_effect_random, plot_mu_effect_random

# %%
plot_n_generated_effect_random()
# Out:
# Generating and evaluating:  25%|##5       | 1/4 [00:00<00:01,  2.70it/s]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2]],
#  'criteria': [0, 1, 2],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 32,
#  'profiles': array([[ 5,  7,  6],
#        [13, 14, 15]])}
#
# ## Restoration rate : 	 90.625%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[307  25   0]
# 	 [ 53 271  10]
# 	 [  1 140 193]]
# => Accuracy :	 0.77
# => Precision :	 0.81
# => Recall :	 0.77
# => F1 :	 0.77
# Generating and evaluating:  50%|#####     | 2/4 [00:00<00:00,  2.64it/s]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2]],
#  'criteria': [0, 1, 2],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 64,
#  'profiles': array([[ 2,  5,  1],
#        [ 3,  8, 14]])}
#
# ## Restoration rate : 	 98.4375%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[332   0   0]
# 	 [ 27 278  29]
# 	 [  0   7 327]]
# => Accuracy :	 0.94
# => Precision :	 0.94
# => Recall :	 0.94
# => F1 :	 0.94
# Generating and evaluating:  75%|#######5  | 3/4 [00:03<00:01,  1.54s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2]],
#  'criteria': [0, 1, 2],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 256,
#  'profiles': array([[13,  2,  9],
#        [14,  5, 19]])}
#
# ## Restoration rate : 	 98.828125%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[323   9   0]
# 	 [ 32 302   0]
# 	 [  0   0 334]]
# => Accuracy :	 0.96
# => Precision :	 0.96
# => Recall :	 0.96
# => F1 :	 0.96
# Generating and evaluating: 100%|##########| 4/4 [00:32<00:00,  8.10s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2]],
#  'criteria': [0, 1, 2],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 512,
#  'profiles': array([[ 2,  5,  8],
#        [10, 13, 12]])}
#
# ## Restoration rate : 	 99.8046875%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[317  15   0]
# 	 [  0 332   2]
# 	 [  0   3 331]]
# => Accuracy :	 0.98
# => Precision :	 0.98
# => Recall :	 0.98
# => F1 :	 0.98

# %%
plot_n_effect_random()
# Out:
# Generating and evaluating:  25%|##5       | 1/4 [00:00<00:00,  3.08it/s]
# Parameters:
# ********************
# {'coalitions': [[0], [1]],
#  'criteria': [0, 1],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 128,
#  'profiles': array([[ 2, 10],
#        [14, 18]])}
#
# ## Restoration rate : 	 97.65625%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[315  17   0]
# 	 [  0 331   3]
# 	 [  0  50 284]]
# => Accuracy :	 0.93
# => Precision :	 0.94
# => Recall :	 0.93
# => F1 :	 0.93
# Generating and evaluating:  50%|#####     | 2/4 [00:01<00:01,  1.46it/s]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2]],
#  'criteria': [0, 1, 2],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 128,
#  'profiles': array([[13,  4, 12],
#        [18, 19, 15]])}
#
# ## Restoration rate : 	 96.875%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[332   0   0]
# 	 [ 45 289   0]
# 	 [  0   5 329]]
# => Accuracy :	 0.95
# => Precision :	 0.95
# => Recall :	 0.95
# => F1 :	 0.95
# Generating and evaluating:  75%|#######5  | 3/4 [00:03<00:01,  1.51s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2], [3], [4]],
#  'criteria': [0, 1, 2, 3, 4],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 128,
#  'profiles': array([[ 3, 10,  7,  1,  4],
#        [ 9, 19, 14, 19, 13]])}
#
# ## Restoration rate : 	 96.09375%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[331   1   0]
# 	 [ 40 284  10]
# 	 [  0   1 333]]
# => Accuracy :	 0.95
# => Precision :	 0.95
# => Recall :	 0.95
# => F1 :	 0.95
# Generating and evaluating: 100%|##########| 4/4 [00:11<00:00,  2.79s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2], [3], [4], [5], [6]],
#  'criteria': [0, 1, 2, 3, 4, 5, 6],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 128,
#  'profiles': array([[ 1,  7,  4,  8,  1,  6, 11],
#        [14, 14, 11, 19,  9, 16, 17]])}
#
# ## Restoration rate : 	 92.96875%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[279  53   0]
# 	 [ 89 243   2]
# 	 [  0   2 332]]
# => Accuracy :	 0.85
# => Precision :	 0.86
# => Recall :	 0.85
# => F1 :	 0.85

# %%
plot_mu_effect_random()
# Out:
# Generating and evaluating:  20%|##        | 1/5 [00:03<00:13,  3.31s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2], [3], [4]],
#  'criteria': [0, 1, 2, 3, 4],
#  'mu': 0.0,
#  'n_ground_truth': 1000,
#  'n_learning_set': 128,
#  'profiles': array([[ 2, 16,  4,  2,  8],
#        [ 9, 19,  8, 19, 19]])}
#
# ## Restoration rate : 	 79.6875%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[312  12   8]
# 	 [ 22 109 203]
# 	 [  0   0 334]]
# => Accuracy :	 0.76
# => Precision :	 0.82
# => Recall :	 0.76
# => F1 :	 0.73
# Generating and evaluating:  40%|####      | 2/5 [00:07<00:11,  3.83s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2], [3], [4]],
#  'criteria': [0, 1, 2, 3, 4],
#  'mu': 0.01,
#  'n_ground_truth': 1000,
#  'n_learning_set': 128,
#  'profiles': array([[ 2,  6, 15, 16, 12],
#        [ 6, 17, 16, 17, 18]])}
#
# ## Restoration rate : 	 73.4375%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[324   2   6]
# 	 [  0  70 264]
# 	 [  0   2 332]]
# => Accuracy :	 0.73
# => Precision :	 0.83
# => Recall :	 0.73
# => F1 :	 0.68
# Generating and evaluating:  60%|######    | 3/5 [00:13<00:09,  4.76s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2], [3], [4]],
#  'criteria': [0, 1, 2, 3, 4],
#  'mu': 0.05,
#  'n_ground_truth': 1000,
#  'n_learning_set': 128,
#  'profiles': array([[ 3, 14,  5,  3,  5],
#        [11, 16, 18,  8, 16]])}
#
# ## Restoration rate : 	 100.0%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[314  18   0]
# 	 [  3 314  17]
# 	 [  0   4 330]]
# => Accuracy :	 0.96
# => Precision :	 0.96
# => Recall :	 0.96
# => F1 :	 0.96
# Generating and evaluating:  80%|########  | 4/5 [00:19<00:05,  5.15s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2], [3], [4]],
#  'criteria': [0, 1, 2, 3, 4],
#  'mu': 0.1,
#  'n_ground_truth': 1000,
#  'n_learning_set': 128,
#  'profiles': array([[ 3,  9, 16,  4,  6],
#        [ 7, 15, 19, 10,  7]])}
#
# ## Restoration rate : 	 91.40625%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[228 104   0]
# 	 [ 34 296   4]
# 	 [  1  18 315]]
# => Accuracy :	 0.84
# => Precision :	 0.85
# => Recall :	 0.84
# => F1 :	 0.84
# Generating and evaluating: 100%|##########| 5/5 [00:38<00:00,  7.65s/it]
# Parameters:
# ********************
# {'coalitions': [[0], [1], [2], [3], [4]],
#  'criteria': [0, 1, 2, 3, 4],
#  'mu': 0.2,
#  'n_ground_truth': 1000,
#  'n_learning_set': 128,
#  'profiles': array([[ 7, 12,  4,  7,  6],
#        [19, 17,  9, 16,  7]])}
#
# ## Restoration rate : 	 88.28125%
# ## Generalization Indexes :
# => Confusion Matrix :
# 	[[272  60   0]
# 	 [ 21 269  44]
# 	 [  1  35 298]]
# => Accuracy :	 0.84
# => Precision :	 0.85
# => Recall :	 0.84
# => F1 :	 0.84
